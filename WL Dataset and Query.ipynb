# %%
from datetime import date
a=date(2000, 1, 2)
my_dict = {a:1}
my_dict.keys()
# Out:
# dict_keys([datetime.date(2000, 1, 2)])

# %%
(lambda x, y: x + y)(1, 2)
# Out:
# 3

# %%
from pandas import DataFrame

# %%
data_frame = DataFrame.from_dict({
    "name": ["Kirill", "Ivan", "Anton"], 
    "age": [31, 26, 40]
})

# %%
data_frame
# Out:
#      name  age
# 0  Kirill   31
# 1    Ivan   26
# 2   Anton   40

# %%
data_frame.set_index("name")
# Out:
#         age
# name
# Kirill   31
# Ivan     26
# Anton    40

# %%
from pandas import DataFrame

my_data = DataFrame.from_dict({
    "name": ["Kirill", "Ivan", "Anton"], 
    "age":  [31, 26, 40]
})

my_data.index=[1, 2]

#my_data.set_index("name")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Kirill\Projects\kirillbelovtest.github.io\WL Dataset and Query.ipynb Cell 7 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Kirill/Projects/kirillbelovtest.github.io/WL%20Dataset%20and%20Query.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> from pandas import DataFrame
#       <a href='vscode-notebook-cell:/c%3A/Users/Kirill/Projects/kirillbelovtest.github.io/WL%20Dataset%20and%20Query.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> my_data = DataFrame.from_dict({
#       <a href='vscode-notebook-cell:/c%3A/Users/Kirill/Projects/kirillbelovtest.github.io/WL%20Dataset%20and%20Query.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     "name": ["Kirill", "Ivan", "Anton"],
# ...

# %%
my_data.loc[1].at("age")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Kirill\Projects\kirillbelovtest.github.io\WL Dataset and Query.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kirill/Projects/kirillbelovtest.github.io/WL%20Dataset%20and%20Query.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> my_data.loc[1].at("age")
#
# TypeError: '_AtIndexer' object is not callable

# %%
df = DataFrame.from_dict({"x": [1, 2, 3], "y": [1, 4, 9]})

# %%
df.set_index("y", inplace=True)

# %%
df.at(1, 9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Kirill\Projects\kirillbelovtest.github.io\WL Dataset and Query.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kirill/Projects/kirillbelovtest.github.io/WL%20Dataset%20and%20Query.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> df.at(1, 9)
#
# TypeError: '_AtIndexer' object is not callable
